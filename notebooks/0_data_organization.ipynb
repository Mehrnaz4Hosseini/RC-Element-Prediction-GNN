# %%
import os
from pathlib import Path
import shutil
import pandas as pd

# %%
folder_path = "/Users/sarayetel/Downloads/TrainData-140411"
all_items = os.listdir(folder_path)
print(f"Total items (files + folders): {len(all_items)}")
# Out:
# Total items (files + folders): 762

# %%
def quick_organize():

    source_folder = "/Users/sarayetel/Downloads/TrainData-140411"
    target_folder =  "/Users/sarayetel/Desktop/Research/Graph/RC-Element-Prediction-GNN/data/train"

    # Create target
    os.makedirs(target_folder, exist_ok=True)
    
    # Get all files sorted alphabetically
    edge_files = sorted(Path(source_folder).glob("Edge-*.xlsx"))
    edge_files.extend(sorted(Path(source_folder).glob("Edge-*.xls")))
    
    feature_files = sorted(Path(source_folder).glob("Feature-*.xlsx"))
    feature_files.extend(sorted(Path(source_folder).glob("Feature-*.xls")))
    
    label_files = sorted(Path(source_folder).glob("Label-*.xlsx"))
    label_files.extend(sorted(Path(source_folder).glob("Label-*.xls")))
    
    # How many complete sets can we make?
    max_sets = min(len(edge_files), len(feature_files), len(label_files))
    
    print(f"Found: {len(edge_files)} Edge, {len(feature_files)} Feature, {len(label_files)} Label")
    print(f"Creating {max_sets} sample folders...\n")
    
    # Create folders
    for i in range(max_sets):
        sample_num = i + 1
        sample_name = f"sample_{sample_num}"
        sample_path = os.path.join(target_folder, sample_name)
        os.makedirs(sample_path, exist_ok=True)
        
        # Get files for this sample
        edge_file = edge_files[i]
        feature_file = feature_files[i]
        label_file = label_files[i]
        
        # Move files
        shutil.copy(str(edge_file), os.path.join(sample_path, edge_file.name))
        shutil.copy(str(feature_file), os.path.join(sample_path, feature_file.name))
        shutil.copy(str(label_file), os.path.join(sample_path, label_file.name))
        
        print(f"✅ sample_{sample_num}:")
        print(f"   {edge_file.name}")
        print(f"   {feature_file.name}")
        print(f"   {label_file.name}\n")
    
    print(f"Done! Created {max_sets} sample folders")
    
    # Count remaining
    remaining = (len(edge_files) - max_sets) + (len(feature_files) - max_sets) + (len(label_files) - max_sets)
    if remaining > 0:
        print(f"\n⚠️  {remaining} files remain unorganized (incomplete sets)")

quick_organize()
# Out:
# Found: 254 Edge, 254 Feature, 254 Label
# Creating 254 sample folders...
#
# ✅ sample_1:
#    Edge-02-shahidi.xlsx
#    Feature-02-shahidi.xlsx
#    Label-02-shahidi.xlsx
#
# ✅ sample_2:
#    Edge-03-yeganeh-bahriyeh.xlsx
#    Feature-03-yeganeh-bahriyeh.xlsx
#    Label-03-yeganeh-bahriyeh.xlsx
#
# ✅ sample_3:
#    Edge-04-habibi-ejraee-asadi.xlsx
#    Feature-04-habibi-ejraee-asadi.xlsx
#    Label-04-habibi-ejraee-asadi.xlsx
#
# ✅ sample_4:
#    Edge-12-shahbazi-ejraee.xlsx
#    Feature-12-shahbazi-ejraee.xlsx
#    Label-12-shahbazi-ejraee.xlsx
#
# ✅ sample_5:
#    Edge-12.xlsx
#    Feature-12.xlsx
#    Label-12.xlsx
#
# ✅ sample_6:
#    Edge-13 kashanian ej 02.xlsx
#    Feature-13 kashanian ej 02.xlsx
#    Label-13 kashanian ej 02.xlsx
#
# ✅ sample_7:
#    Edge-13-mokhtari-sayyani.xlsx
#    Feature-13-mokhtari-sayyani.xlsx
#    Label-13-mokhtari-sayyani.xlsx
#
# ✅ sample_8:
#    Edge-13.xlsx
#    Feature-13.xlsx
#    Label-13.xlsx
#
# ✅ sample_9:
#    Edge-14.xlsx
#    Feature-14.xlsx
#    Label-14.xlsx
#
# ✅ sample_10:
#    Edge-16.xlsx
#    Feature-16.xlsx
#    Label-16.xlsx
#
# ✅ sample_11:
#    Edge-17.xlsx
#    Feature-17.xlsx
#    Label-17.xlsx
#
# ✅ sample_12:
#    Edge-18.xlsx
#    Feature-18.xlsx
#    Label-18.xlsx
#
# ✅ sample_13:
#    Edge-19-zafari-ejraee.xlsx
#    Feature-19-zafari-ejraee.xlsx
#    Label-19-zafari-ejraee.xlsx
#
# ✅ sample_14:
#    Edge-19.xlsx
#    Feature-19.xlsx
#    Label-19.xlsx
#
# ✅ sample_15:
#    Edge-2.xlsx
#    Feature-2.xlsx
#    Label-2.xlsx
#
# ✅ sample_16:
#    Edge-23-mostaghimi.xlsx
#    Feature-23-mostaghimi.xlsx
#    Label-23-mostaghimi.xlsx
#
# ✅ sample_17:
#    Edge-25-akbar azizi.xlsx
#    Feature-25-akbar azizi.xlsx
#    Label-25-akbar azizi.xlsx
#
# ✅ sample_18:
#    Edge-26 bagheri ej 4.xlsx
#    Feature-26 bagheri ej 4.xlsx
#    Label-26 bagheri ej 4.xlsx
#
# ✅ sample_19:
#    Edge-26-mehri sadeghi.xlsx
#    Feature-26-mehri sadeghi.xlsx
#    Label-26-mehri sadeghi.xlsx
#
# ✅ sample_20:
#    Edge-3.xlsx
#    Feature-3.xlsx
#    Label-3.xlsx
#
# ✅ sample_21:
#    Edge-326 mohammadi ejjjjjj.xlsx
#    Feature-326 mohammadi ejjjjjj.xlsx
#    Label-326 mohammadi ejjjjjj.xlsx
#
# ✅ sample_22:
#    Edge-343 fahimi ej.xlsx
#    Feature-343 fahimi ej.xlsx
#    Label-343 fahimi ej.xlsx
#
# ✅ sample_23:
#    Edge-35-sayyani.xlsx
#    Feature-35-sayyani.xlsx
#    Label-35-sayyani.xlsx
#
# ✅ sample_24:
#    Edge-356 farokhi ej.xlsx
#    Feature-356 farokhi ej.xlsx
#    Label-356 farokhi ej.xlsx
#
# ✅ sample_25:
#    Edge-369 ghanbari-tehran ej.xlsx
#    Feature-369 ghanbari-tehran ej.xlsx
#    Label-369 ghanbari-tehran ej.xlsx
#
# ✅ sample_26:
#    Edge-39-moraffah-hemmati.xlsx
#    Feature-39-moraffah-hemmati.xlsx
#    Label-39-moraffah-hemmati.xlsx
#
# ✅ sample_27:
#    Edge-4-05-abdollahi1.xlsx
#    Feature-4-05-abdollahi1.xlsx
#    Label-4-05-abdollahi1.xlsx
#
# ✅ sample_28:
#    Edge-4.xlsx
#    Feature-4.xlsx
#    Label-4.xlsx
#
# ✅ sample_29:
#    Edge-439 abdollahi ej 02.xlsx
#    Feature-439 abdollahi ej 02.xlsx
#    Label-439 abdollahi ej 02.xlsx
#
# ✅ sample_30:
#    Edge-460 mireei PACK.xlsx
#    Feature-460 mireei PACK.xlsx
#    Label-460 mireei PACK.xlsx
#
# ✅ sample_31:
#    Edge-466 hasani manesh ej.xlsx
#    Feature-466 hasani manesh ej.xlsx
#    Label-466 hasani manesh ej.xlsx
#
# ✅ sample_32:
#    Edge-469 omali ej 03a.xlsx
#    Feature-469 omali ej 03a.xlsx
#    Label-469 omali ej 03a.xlsx
#
# ✅ sample_33:
#    Edge-473 zafari PACK.xlsx
#    Feature-473 zafari PACK.xlsx
#    Label-473 zafari PACK.xlsx
#
# ✅ sample_34:
#    Edge-482 rahimi mehr PACK.xlsx
#    Feature-482 rahimi mehr PACK.xlsx
#    Label-482 rahimi mehr PACK.xlsx
#
# ✅ sample_35:
#    Edge-5-05-abdollahi2.xlsx
#    Feature-5-05-abdollahi2.xlsx
#    Label-5-05-abdollahi2.xlsx
#
# ✅ sample_36:
#    Edge-5-Story 01.xlsx
#    Feature-5-Story 01.xlsx
#    Label-5-Story 01.xlsx
#
# ✅ sample_37:
#    Edge-5.xlsx
#    Feature-5.xlsx
#    Label-5.xlsx
#
# ✅ sample_38:
#    Edge-6.xlsx
#    Feature-6.xlsx
#    Label-6.xlsx
#
# ✅ sample_39:
#    Edge-604 dadban ej.xlsx
#    Feature-604 dadban ej.xlsx
#    Label-604 dadban ej.xlsx
#
# ✅ sample_40:
#    Edge-610 karimi ej1404.xlsx
#    Feature-610 karimi ej1404.xlsx
#    Label-610 karimi ej1404.xlsx
#
# ✅ sample_41:
#    Edge-63-nazari-ezzati.xlsx
#    Feature-63-nazari-ezzati.xlsx
#    Label-63-nazari-ezzati.xlsx
#
# ✅ sample_42:
#    Edge-7-Story 03.xlsx
#    Feature-7-Story 03.xlsx
#    Label-7-Story 03.xlsx
#
# ✅ sample_43:
#    Edge-7.xlsx
#    Feature-7.xlsx
#    Label-7.xlsx
#
# ✅ sample_44:
#    Edge-79-maktabdar-tahereh abbasi.xlsx
#    Feature-79-maktabdar-tahereh abbasi.xlsx
#    Label-79-maktabdar-tahereh abbasi.xlsx
#
# ✅ sample_45:
#    Edge-7ST.xlsx
#    Feature-7ST.xlsx
#    Label-7ST.xlsx
#
# ✅ sample_46:
#    Edge-8.xlsx
#    Feature-8.xlsx
#    Label-8.xlsx
#
# ✅ sample_47:
#    Edge-Aalaee Ejraee.xlsx
#    Feature-Aalaee Ejraee.xlsx
#    Label-Aalaee Ejraee.xlsx
#
# ✅ sample_48:
#    Edge-Aalaee Sazmani.xlsx
#    Feature-Aalaee Sazmani.xlsx
#    Label-Aalaee Sazmani.xlsx
#
# ✅ sample_49:
#    Edge-Abbasi.xlsx
#    Feature-Abbasi.xlsx
#    Label-Abbasi.xlsx
#
# ✅ sample_50:
#    Edge-AliMohamadiyan2.xlsx
#    Feature-AliMohamadiyan2.xlsx
#    Label-AliMohamadiyan2.xlsx
#
# ✅ sample_51:
#    Edge-Alireza mohamadi1.xlsx
#    Feature-Alireza mohamadi1.xlsx
#    Label-Alireza mohamadi1.xlsx
#
# ✅ sample_52:
#    Edge-Alireza mohamadi2.xlsx
#    Feature-Alireza mohamadi2.xlsx
#    Label-Alireza mohamadi2.xlsx
#
# ✅ sample_53:
#    Edge-Almasi.xlsx
#    Feature-Almasi.xlsx
#    Label-Almasi.xlsx
#
# ✅ sample_54:
#    Edge-Alvand Ejraee.xlsx
#    Feature-Alvand Ejraee.xlsx
#    Label-Alvand Ejraee.xlsx
#
# ✅ sample_55:
#    Edge-Amini 03.xlsx
#    Feature-Amini 03.xlsx
#    Label-Amini 03.xlsx
#
# ✅ sample_56:
#    Edge-Amini Ejraei 09.xlsx
#    Feature-Amini Ejraei 09.xlsx
#    Label-Amini Ejraei 09.xlsx
#
# ✅ sample_57:
#    Edge-Amjadi.xlsx
#    Feature-Amjadi.xlsx
#    Label-Amjadi.xlsx
#
# ✅ sample_58:
#    Edge-Arezomandi.xlsx
#    Feature-Arezomandi.xlsx
#    Label-Arezomandi.xlsx
#
# ✅ sample_59:
#    Edge-Ashjaei .xlsx
#    Feature-Ashjaei .xlsx
#    Label-Ashjaei .xlsx
#
# ✅ sample_60:
#    Edge-BLOOK-T.xlsx
#    Feature-BLOOK-T.xlsx
#    Label-BLOOK-T.xlsx
#
# ✅ sample_61:
#    Edge-B_DavoodKhorasani.xlsx
#    Feature-B_DavoodKhorasani.xlsx
#    Label-B_DavoodKhorasani.xlsx
#
# ✅ sample_62:
#    Edge-B_GhorbanAli.xlsx
#    Feature-B_GhorbanAli.xlsx
#    Label-B_GhorbanAli.xlsx
#
# ✅ sample_63:
#    Edge-B_HajiAliGol.xlsx
#    Feature-B_HajiAliGol.xlsx
#    Label-B_HajiAliGol.xlsx
#
# ✅ sample_64:
#    Edge-B_KarimKhah.xlsx
#    Feature-B_KarimKhah.xlsx
#    Label-B_KarimKhah.xlsx
#
# ✅ sample_65:
#    Edge-B_MohammadAliBeik.xlsx
#    Feature-B_MohammadAliBeik.xlsx
#    Label-B_MohammadAliBeik.xlsx
#
# ✅ sample_66:
#    Edge-B_MohammadHosseinPor.xlsx
#    Feature-B_MohammadHosseinPor.xlsx
#    Label-B_MohammadHosseinPor.xlsx
#
# ✅ sample_67:
#    Edge-B_Rahmani.xlsx
#    Feature-B_Rahmani.xlsx
#    Label-B_Rahmani.xlsx
#
# ✅ sample_68:
#    Edge-B_Yosefi.xlsx
#    Feature-B_Yosefi.xlsx
#    Label-B_Yosefi.xlsx
#
# ✅ sample_69:
#    Edge-B_Zand.xlsx
#    Feature-B_Zand.xlsx
#    Label-B_Zand.xlsx
#
# ✅ sample_70:
#    Edge-Bagheri.xlsx
#    Feature-Bagheri.xlsx
#    Label-Bagheri.xlsx
#
# ✅ sample_71:
#    Edge-Baha-o-ddini 03.xlsx
#    Feature-Baha-o-ddini 03.xlsx
#    Label-Baha-o-ddini 03.xlsx
#
# ✅ sample_72:
#    Edge-Bayaty.xlsx
#    Feature-Bayaty.xlsx
#    Label-Bayaty.xlsx
#
# ✅ sample_73:
#    Edge-BeikLoo.xlsx
#    Feature-BeikLoo.xlsx
#    Label-BeikLoo.xlsx
#
# ✅ sample_74:
#    Edge-Bigdeli.xlsx
#    Feature-Bigdeli.xlsx
#    Label-Bigdeli.xlsx
#
# ✅ sample_75:
#    Edge-Bitarafan 04.xlsx
#    Feature-Bitarafan 04.xlsx
#    Label-Bitarafan 04.xlsx
#
# ✅ sample_76:
#    Edge-Block A-02.xlsx
#    Feature-Block A-02.xlsx
#    Label-Block A-02.xlsx
#
# ✅ sample_77:
#    Edge-Block B-02.xlsx
#    Feature-Block B-02.xlsx
#    Label-Block B-02.xlsx
#
# ✅ sample_78:
#    Edge-Block-B 07.xlsx
#    Feature-Block-B 07.xlsx
#    Label-Block-B 07.xlsx
#
# ✅ sample_79:
#    Edge-CE0034-zaeri.xlsx
#    Feature-CE0034-zaeri.xlsx
#    Label-CE0034-zaeri.xlsx
#
# ✅ sample_80:
#    Edge-CE0157-Loghman.xlsx
#    Feature-CE0157-Loghman.xlsx
#    Label-CE0157-Loghman.xlsx
#
# ✅ sample_81:
#    Edge-CE0158-Oghaf.xlsx
#    Feature-CE0158-Oghaf.xlsx
#    Label-CE0158-Oghaf.xlsx
#
# ✅ sample_82:
#    Edge-CE0159-MasjedAkbari.xlsx
#    Feature-CE0159-MasjedAkbari.xlsx
#    Label-CE0159-MasjedAkbari.xlsx
#
# ✅ sample_83:
#    Edge-CE0160-masjedakbari3.xlsx
#    Feature-CE0160-masjedakbari3.xlsx
#    Label-CE0160-masjedakbari3.xlsx
#
# ✅ sample_84:
#    Edge-CE0161-Farhadi.xlsx
#    Feature-CE0161-Farhadi.xlsx
#    Label-CE0161-Farhadi.xlsx
#
# ✅ sample_85:
#    Edge-CE0162-Rezazade.xlsx
#    Feature-CE0162-Rezazade.xlsx
#    Label-CE0162-Rezazade.xlsx
#
# ✅ sample_86:
#    Edge-CE0164-Kakavand.xlsx
#    Feature-CE0164-Kakavand.xlsx
#    Label-CE0164-Kakavand.xlsx
#
# ✅ sample_87:
#    Edge-CE0166-EramB'.xlsx
#    Feature-CE0166-EramB'.xlsx
#    Label-CE0166-EramB'.xlsx
#
# ✅ sample_88:
#    Edge-CE0167-EramILeft.xlsx
#    Feature-CE0167-EramILeft.xlsx
#    Label-CE0167-EramILeft.xlsx
#
# ✅ sample_89:
#    Edge-CE0167-EramIRight.xlsx
#    Feature-CE0167-EramIRight.xlsx
#    Label-CE0167-EramIRight.xlsx
#
# ✅ sample_90:
#    Edge-CE0168-EramH.xlsx
#    Feature-CE0168-EramH.xlsx
#    Label-CE0168-EramH.xlsx
#
# ✅ sample_91:
#    Edge-CE0169-EramA.xlsx
#    Feature-CE0169-EramA.xlsx
#    Label-CE0169-EramA.xlsx
#
# ✅ sample_92:
#    Edge-CE0171-Mohamadkhani.xlsx
#    Feature-CE0171-Mohamadkhani.xlsx
#    Label-CE0171-Mohamadkhani.xlsx
#
# ✅ sample_93:
#    Edge-CE0276-EramEBot.xlsx
#    Feature-CE0276-EramEBot.xlsx
#    Label-CE0276-EramEBot.xlsx
#
# ✅ sample_94:
#    Edge-CE0276-EramETop.xlsx
#    Feature-CE0276-EramETop.xlsx
#    Label-CE0276-EramETop.xlsx
#
# ✅ sample_95:
#    Edge-CE0277-EramFBot.xlsx
#    Feature-CE0277-EramFBot.xlsx
#    Label-CE0277-EramFBot.xlsx
#
# ✅ sample_96:
#    Edge-CE0278-Zand.xlsx
#    Feature-CE0278-Zand.xlsx
#    Label-CE0278-Zand.xlsx
#
# ✅ sample_97:
#    Edge-CE0279-Aghamiri.xlsx
#    Feature-CE0279-Aghamiri.xlsx
#    Label-CE0279-Aghamiri.xlsx
#
# ✅ sample_98:
#    Edge-CE0280-EramDBot.xlsx
#    Feature-CE0280-EramDBot.xlsx
#    Label-CE0280-EramDBot.xlsx
#
# ✅ sample_99:
#    Edge-CE0280-EramDTop.xlsx
#    Feature-CE0280-EramDTop.xlsx
#    Label-CE0280-EramDTop.xlsx
#
# ✅ sample_100:
#    Edge-CE0281-Soltani.xlsx
#    Feature-CE0281-Soltani.xlsx
#    Label-CE0281-Soltani.xlsx
#
# ✅ sample_101:
#    Edge-CE0284-mollavi.xlsx
#    Feature-CE0284-mollavi.xlsx
#    Label-CE0284-mollavi.xlsx
#
# ✅ sample_102:
#    Edge-CE0285-EramJ.xlsx
#    Feature-CE0285-EramJ.xlsx
#    Label-CE0285-EramJ.xlsx
#
# ✅ sample_103:
#    Edge-CE0392-DadgostariD.xlsx
#    Feature-CE0392-DadgostariD.xlsx
#    Label-CE0392-DadgostariD.xlsx
#
# ✅ sample_104:
#    Edge-CE9922-hatami.xlsx
#    Feature-CE9922-hatami.xlsx
#    Label-CE9922-hatami.xlsx
#
# ✅ sample_105:
#    Edge-Chegini Sazmani B1.xlsx
#    Feature-Chegini Sazmani B1.xlsx
#    Label-Chegini Sazmani B1.xlsx
#
# ✅ sample_106:
#    Edge-Chegini Sazmani B2.xlsx
#    Feature-Chegini Sazmani B2.xlsx
#    Label-Chegini Sazmani B2.xlsx
#
# ✅ sample_107:
#    Edge-Cheraghi.xlsx
#    Feature-Cheraghi.xlsx
#    Label-Cheraghi.xlsx
#
# ✅ sample_108:
#    Edge-Dehghan.xlsx
#    Feature-Dehghan.xlsx
#    Label-Dehghan.xlsx
#
# ✅ sample_109:
#    Edge-Dejamkhoo Sazmani.xlsx
#    Feature-Dejamkhoo Sazmani.xlsx
#    Label-Dejamkhoo Sazmani.xlsx
#
# ✅ sample_110:
#    Edge-EC0275-EramCLeft.xlsx
#    Feature-EC0275-EramCLeft.xlsx
#    Label-EC0275-EramCLeft.xlsx
#
# ✅ sample_111:
#    Edge-EC0275-EramCRight.xlsx
#    Feature-EC0275-EramCRight.xlsx
#    Label-EC0275-EramCRight.xlsx
#
# ✅ sample_112:
#    Edge-Education Department1.xlsx
#    Feature-Education Department1.xlsx
#    Label-Education Department1.xlsx
#
# ✅ sample_113:
#    Edge-Education Department2.xlsx
#    Feature-Education Department2.xlsx
#    Label-Education Department2.xlsx
#
# ✅ sample_114:
#    Edge-Eng. Ghadiri.xlsx
#    Feature-Eng. Ghadiri.xlsx
#    Label-Eng. Ghadiri.xlsx
#
# ✅ sample_115:
#    Edge-Esmaeili_Ejraei_V13.xlsx
#    Feature-Esmaeili_Ejraei_V13.xlsx
#    Label-Esmaeili_Ejraei_V13.xlsx
#
# ✅ sample_116:
#    Edge-Farshadi.xlsx
#    Feature-Farshadi.xlsx
#    Label-Farshadi.xlsx
#
# ✅ sample_117:
#    Edge-Farzane pardisan.xlsx
#    Feature-Farzane pardisan.xlsx
#    Label-Farzane pardisan.xlsx
#
# ✅ sample_118:
#    Edge-Ghadir-04.xlsx
#    Feature-Ghadir-04.xlsx
#    Label-Ghadir-04.xlsx
#
# ✅ sample_119:
#    Edge-Ghasemi2.xlsx
#    Feature-Ghasemi2.xlsx
#    Label-Ghasemi2.xlsx
#
# ✅ sample_120:
#    Edge-Ghasemi6.xlsx
#    Feature-Ghasemi6.xlsx
#    Label-Ghasemi6.xlsx
#
# ✅ sample_121:
#    Edge-Ghods.xlsx
#    Feature-Ghods.xlsx
#    Label-Ghods.xlsx
#
# ✅ sample_122:
#    Edge-Gholi Ejraee.xlsx
#    Feature-Gholi Ejraee.xlsx
#    Label-Gholi Ejraee.xlsx
#
# ✅ sample_123:
#    Edge-HASANAGHAMOHAMMADI.xlsx
#    Feature-HASANAGHAMOHAMMADI.xlsx
#    Label-HASANAGHAMOHAMMADI.xlsx
#
# ✅ sample_124:
#    Edge-HajiHoseini.xlsx
#    Feature-HajiHoseini.xlsx
#    Label-HajiHoseini.xlsx
#
# ✅ sample_125:
#    Edge-Hajizade Ejraei 03.xlsx
#    Feature-Hajizade Ejraei 03.xlsx
#    Label-Hajizade Ejraei 03.xlsx
#
# ✅ sample_126:
#    Edge-Hamidi Moghaddam.xlsx
#    Feature-Hamidi Moghaddam.xlsx
#    Label-Hamidi Moghaddam.xlsx
#
# ✅ sample_127:
#    Edge-Hashem Tejarat.xlsx
#    Feature-Hashem Tejarat.xlsx
#    Label-Hashem Tejarat.xlsx
#
# ✅ sample_128:
#    Edge-Hashemi.xlsx
#    Feature-Hashemi.xlsx
#    Label-Hashemi.xlsx
#
# ✅ sample_129:
#    Edge-Hayatbakhsh.xlsx
#    Feature-Hayatbakhsh.xlsx
#    Label-Hayatbakhsh.xlsx
#
# ✅ sample_130:
#    Edge-Heydari 02.xlsx
#    Feature-Heydari 02.xlsx
#    Label-Heydari 02.xlsx
#
# ✅ sample_131:
#    Edge-Heydari1.xlsx
#    Feature-Heydari1.xlsx
#    Label-Heydari1.xlsx
#
# ✅ sample_132:
#    Edge-Heydari2.xlsx
#    Feature-Heydari2.xlsx
#    Label-Heydari2.xlsx
#
# ✅ sample_133:
#    Edge-Jahangiri 02.xlsx
#    Feature-Jahangiri 02.xlsx
#    Label-Jahangiri 02.xlsx
#
# ✅ sample_134:
#    Edge-Javadi Pour.xlsx
#    Feature-Javadi Pour.xlsx
#    Label-Javadi Pour.xlsx
#
# ✅ sample_135:
#    Edge-Kaj 04.xlsx
#    Feature-Kaj 04.xlsx
#    Label-Kaj 04.xlsx
#
# ✅ sample_136:
#    Edge-Kakolivand Ejraee.xlsx
#    Feature-Kakolivand Ejraee.xlsx
#    Label-Kakolivand Ejraee.xlsx
#
# ✅ sample_137:
#    Edge-Karami.xlsx
#    Feature-Karami.xlsx
#    Label-Karami.xlsx
#
# ✅ sample_138:
#    Edge-Karegar.xlsx
#    Feature-Karegar.xlsx
#    Label-Karegar.xlsx
#
# ✅ sample_139:
#    Edge-Karimi Sazmani.xlsx
#    Feature-Karimi Sazmani.xlsx
#    Label-Karimi Sazmani.xlsx
#
# ✅ sample_140:
#    Edge-Karimi.xlsx
#    Feature-Karimi.xlsx
#    Label-Karimi.xlsx
#
# ✅ sample_141:
#    Edge-Keshavarz.xlsx
#    Feature-Keshavarz.xlsx
#    Label-Keshavarz.xlsx
#
# ✅ sample_142:
#    Edge-Khobroi.xlsx
#    Feature-Khobroi.xlsx
#    Label-Khobroi.xlsx
#
# ✅ sample_143:
#    Edge-Khoshraftar Ejraee.xlsx
#    Feature-Khoshraftar Ejraee.xlsx
#    Label-Khoshraftar Ejraee.xlsx
#
# ✅ sample_144:
#    Edge-MASKAN MELI E.xlsx
#    Feature-MASKAN MELI E.xlsx
#    Label-MASKAN MELI E.xlsx
#
# ✅ sample_145:
#    Edge-Mehdi.xlsx
#    Feature-Mehdi.xlsx
#    Label-Mehdi.xlsx
#
# ✅ sample_146:
#    Edge-Memerzade.xlsx
#    Feature-Memerzade.xlsx
#    Label-Memerzade.xlsx
#
# ✅ sample_147:
#    Edge-Mohammadi 03 (3).xlsx
#    Feature-Mohammadi 03 (3).xlsx
#    Label-Mohammadi 03 (3).xlsx
#
# ✅ sample_148:
#    Edge-Mohammadi 04 (2).xlsx
#    Feature-Mohammadi 04 (2).xlsx
#    Label-Mohammadi 04 (2).xlsx
#
# ✅ sample_149:
#    Edge-Moradi Sazmani.xlsx
#    Feature-Moradi Sazmani.xlsx
#    Label-Moradi Sazmani.xlsx
#
# ✅ sample_150:
#    Edge-Mosque No.1.xlsx
#    Feature-Mosque No.1.xlsx
#    Label-Mosque No.1.xlsx
#
# ✅ sample_151:
#    Edge-Movahedi Main.xlsx
#    Feature-Movahedi Main.xlsx
#    Label-Movahedi Main.xlsx
#
# ✅ sample_152:
#    Edge-Namian.xlsx
#    Feature-Namian.xlsx
#    Label-Namian.xlsx
#
# ✅ sample_153:
#    Edge-Nariman.xlsx
#    Feature-Nariman.xlsx
#    Label-Nariman.xlsx
#
# ✅ sample_154:
#    Edge-Nejati 03.xlsx
#    Feature-Nejati 03.xlsx
#    Label-Nejati 03.xlsx
#
# ✅ sample_155:
#    Edge-Nikokalam 07.xlsx
#    Feature-Nikokalam 07.xlsx
#    Label-Nikokalam 07.xlsx
#
# ✅ sample_156:
#    Edge-Norouzi 04.xlsx
#    Feature-Norouzi 04.xlsx
#    Label-Norouzi 04.xlsx
#
# ✅ sample_157:
#    Edge-Octagonal Mosque.xlsx
#    Feature-Octagonal Mosque.xlsx
#    Label-Octagonal Mosque.xlsx
#
# ✅ sample_158:
#    Edge-Pajoheshgah 04.xlsx
#    Feature-Pajoheshgah 04.xlsx
#    Label-Pajoheshgah 04.xlsx
#
# ✅ sample_159:
#    Edge-Pasdaran.xlsx
#    Feature-Pasdaran.xlsx
#    Label-Pasdaran.xlsx
#
# ✅ sample_160:
#    Edge-Pashazade.xlsx
#    Feature-Pashazade.xlsx
#    Label-Pashazade.xlsx
#
# ✅ sample_161:
#    Edge-Pousti.xlsx
#    Feature-Pousti.xlsx
#    Label-Pousti.xlsx
#
# ✅ sample_162:
#    Edge-Qomi.xlsx
#    Feature-Qomi.xlsx
#    Label-Qomi.xlsx
#
# ✅ sample_163:
#    Edge-Rahmani.xlsx
#    Feature-Rahmani.xlsx
#    Label-Rahmani.xlsx
#
# ✅ sample_164:
#    Edge-Ramshak.xlsx
#    Feature-Ramshak.xlsx
#    Label-Ramshak.xlsx
#
# ✅ sample_165:
#    Edge-Raoufi.xlsx
#    Feature-Raoufi.xlsx
#    Label-Raoufi.xlsx
#
# ✅ sample_166:
#    Edge-Rezaee.xlsx
#    Feature-Rezaee.xlsx
#    Label-Rezaee.xlsx
#
# ✅ sample_167:
#    Edge-Sadeghi.xlsx
#    Feature-Sadeghi.xlsx
#    Label-Sadeghi.xlsx
#
# ✅ sample_168:
#    Edge-Saffari 01.xlsx
#    Feature-Saffari 01.xlsx
#    Label-Saffari 01.xlsx
#
# ✅ sample_169:
#    Edge-Salimi 10.xlsx
#    Feature-Salimi 10.xlsx
#    Label-Salimi 10.xlsx
#
# ✅ sample_170:
#    Edge-Sangtarashan 09.xlsx
#    Feature-Sangtarashan 09.xlsx
#    Label-Sangtarashan 09.xlsx
#
# ✅ sample_171:
#    Edge-Shariat.xlsx
#    Feature-Shariat.xlsx
#    Label-Shariat.xlsx
#
# ✅ sample_172:
#    Edge-Sharifi 02.xlsx
#    Feature-Sharifi 02.xlsx
#    Label-Sharifi 02.xlsx
#
# ✅ sample_173:
#    Edge-Sheikhi.xlsx
#    Feature-Sheikhi.xlsx
#    Label-Sheikhi.xlsx
#
# ✅ sample_174:
#    Edge-Sohrab A.xlsx
#    Feature-Sohrab A.xlsx
#    Label-Sohrab A.xlsx
#
# ✅ sample_175:
#    Edge-Sohrab B.xlsx
#    Feature-Sohrab B.xlsx
#    Label-Sohrab B.xlsx
#
# ✅ sample_176:
#    Edge-Sohrab I.xlsx
#    Feature-Sohrab I.xlsx
#    Label-Sohrab I.xlsx
#
# ✅ sample_177:
#    Edge-Sohrab J.xlsx
#    Feature-Sohrab J.xlsx
#    Label-Sohrab J.xlsx
#
# ✅ sample_178:
#    Edge-Sorourian.xlsx
#    Feature-Sorourian.xlsx
#    Label-Sorourian.xlsx
#
# ✅ sample_179:
#    Edge-T- (1).xlsx
#    Feature-T- (1).xlsx
#    Label-T- (1).xlsx
#
# ✅ sample_180:
#    Edge-T- (10).xlsx
#    Feature-T- (10).xlsx
#    Label-T- (10).xlsx
#
# ✅ sample_181:
#    Edge-T- (11).xlsx
#    Feature-T- (11).xlsx
#    Label-T- (11).xlsx
#
# ✅ sample_182:
#    Edge-T- (13).xlsx
#    Feature-T- (13).xlsx
#    Label-T- (13).xlsx
#
# ✅ sample_183:
#    Edge-T- (19).xlsx
#    Feature-T- (19).xlsx
#    Label-T- (19).xlsx
#
# ✅ sample_184:
#    Edge-T- (20).xlsx
#    Feature-T- (20).xlsx
#    Label-T- (20).xlsx
#
# ✅ sample_185:
#    Edge-T- (22).xlsx
#    Feature-T- (22).xlsx
#    Label-T- (22).xlsx
#
# ✅ sample_186:
#    Edge-T- (24).xlsx
#    Feature-T- (24).xlsx
#    Label-T- (24).xlsx
#
# ✅ sample_187:
#    Edge-T- (27).xlsx
#    Feature-T- (27).xlsx
#    Label-T- (27).xlsx
#
# ✅ sample_188:
#    Edge-T- (29).xlsx
#    Feature-T- (29).xlsx
#    Label-T- (29).xlsx
#
# ✅ sample_189:
#    Edge-T- (3).xlsx
#    Feature-T- (3).xlsx
#    Label-T- (3).xlsx
#
# ✅ sample_190:
#    Edge-T- (30).xlsx
#    Feature-T- (30).xlsx
#    Label-T- (30).xlsx
#
# ✅ sample_191:
#    Edge-T- (31).xlsx
#    Feature-T- (31).xlsx
#    Label-T- (31).xlsx
#
# ✅ sample_192:
#    Edge-T- (32).xlsx
#    Feature-T- (32).xlsx
#    Label-T- (32).xlsx
#
# ✅ sample_193:
#    Edge-T- (35).xlsx
#    Feature-T- (35).xlsx
#    Label-T- (35).xlsx
#
# ✅ sample_194:
#    Edge-T- (36).xlsx
#    Feature-T- (36).xlsx
#    Label-T- (36).xlsx
#
# ✅ sample_195:
#    Edge-T- (38).xlsx
#    Feature-T- (38).xlsx
#    Label-T- (38).xlsx
#
# ✅ sample_196:
#    Edge-T- (39).xlsx
#    Feature-T- (39).xlsx
#    Label-T- (39).xlsx
#
# ✅ sample_197:
#    Edge-T- (4).xlsx
#    Feature-T- (4).xlsx
#    Label-T- (4).xlsx
#
# ✅ sample_198:
#    Edge-T- (40).xlsx
#    Feature-T- (40).xlsx
#    Label-T- (40).xlsx
#
# ✅ sample_199:
#    Edge-T- (41).xlsx
#    Feature-T- (41).xlsx
#    Label-T- (41).xlsx
#
# ✅ sample_200:
#    Edge-T- (44).xlsx
#    Feature-T- (44).xlsx
#    Label-T- (44).xlsx
#
# ✅ sample_201:
#    Edge-T- (45).xlsx
#    Feature-T- (45).xlsx
#    Label-T- (45).xlsx
#
# ✅ sample_202:
#    Edge-T- (46).xlsx
#    Feature-T- (46).xlsx
#    Label-T- (46).xlsx
#
# ✅ sample_203:
#    Edge-T- (48).xlsx
#    Feature-T- (48).xlsx
#    Label-T- (48).xlsx
#
# ✅ sample_204:
#    Edge-T- (5).xlsx
#    Feature-T- (5).xlsx
#    Label-T- (5).xlsx
#
# ✅ sample_205:
#    Edge-T- (50).xlsx
#    Feature-T- (50).xlsx
#    Label-T- (50).xlsx
#
# ✅ sample_206:
#    Edge-T- (6).xlsx
#    Feature-T- (6).xlsx
#    Label-T- (6).xlsx
#
# ✅ sample_207:
#    Edge-T- (7).xlsx
#    Feature-T- (7).xlsx
#    Label-T- (7).xlsx
#
# ✅ sample_208:
#    Edge-T- (8).xlsx
#    Feature-T- (8).xlsx
#    Label-T- (8).xlsx
#
# ✅ sample_209:
#    Edge-T-37.xlsx
#    Feature-T-37.xlsx
#    Label-T-37.xlsx
#
# ✅ sample_210:
#    Edge-TABA.xlsx
#    Feature-TABA.xlsx
#    Label-TABA.xlsx
#
# ✅ sample_211:
#    Edge-Top4.xlsx
#    Feature-Top4.xlsx
#    Label-Top4.xlsx
#
# ✅ sample_212:
#    Edge-Vahidi Ej .xlsx
#    Feature-Vahidi Ej .xlsx
#    Label-Vahidi Ej .xlsx
#
# ✅ sample_213:
#    Edge-Vanak.xlsx
#    Feature-Vanak.xlsx
#    Label-Vanak.xlsx
#
# ✅ sample_214:
#    Edge-Yari.xlsx
#    Feature-Yari.xlsx
#    Label-Yari.xlsx
#
# ✅ sample_215:
#    Edge-Zamani.xlsx
#    Feature-Zamani.xlsx
#    Label-Zamani.xlsx
#
# ✅ sample_216:
#    Edge-Zare Pour.xlsx
#    Feature-Zare Pour.xlsx
#    Label-Zare Pour.xlsx
#
# ✅ sample_217:
#    Edge-Zeynali.xlsx
#    Feature-Zeynali.xlsx
#    Label-Zeynali.xlsx
#
# ✅ sample_218:
#    Edge-Zojaji.xlsx
#    Feature-Zojaji.xlsx
#    Label-Zojaji.xlsx
#
# ✅ sample_219:
#    Edge-akbari.xlsx
#    Feature-akbari.xlsx
#    Label-akbari.xlsx
#
# ✅ sample_220:
#    Edge-akbarzadeh.xlsx
#    Feature-akbarzadeh.xlsx
#    Label-akbarzadeh.xlsx
#
# ✅ sample_221:
#    Edge-ali hoseini.xlsx
#    Feature-ali hoseini.xlsx
#    Label-ali hoseini.xlsx
#
# ✅ sample_222:
#    Edge-barati.xlsx
#    Feature-barati.xlsx
#    Label-barati.xlsx
#
# ✅ sample_223:
#    Edge-bashari.xlsx
#    Feature-bashari.xlsx
#    Label-bashari.xlsx
#
# ✅ sample_224:
#    Edge-final-axis modify2.xlsx
#    Feature-final-axis modify2.xlsx
#    Label-final-axis modify2.xlsx
#
# ✅ sample_225:
#    Edge-haji.xlsx
#    Feature-haji.xlsx
#    Label-haji.xlsx
#
# ✅ sample_226:
#    Edge-hatefi.xlsx
#    Feature-hatefi.xlsx
#    Label-hatefi.xlsx
#
# ✅ sample_227:
#    Edge-hemes 4.xlsx
#    Feature-hemes 4.xlsx
#    Label-hemes 4.xlsx
#
# ✅ sample_228:
#    Edge-hermes 5.xlsx
#    Feature-hermes 5.xlsx
#    Label-hermes 5.xlsx
#
# ✅ sample_229:
#    Edge-jaffari.xlsx
#    Feature-jaffari.xlsx
#    Label-jaffari.xlsx
#
# ✅ sample_230:
#    Edge-jalali.xlsx
#    Feature-jalali.xlsx
#    Label-jalali.xlsx
#
# ✅ sample_231:
#    Edge-khoshnezhad .xlsx
#    Feature-khoshnezhad .xlsx
#    Label-khoshnezhad .xlsx
#
# ✅ sample_232:
#    Edge-mahmoodi 09.xlsx
#    Feature-mahmoodi 09.xlsx
#    Label-mahmoodi 09.xlsx
#
# ✅ sample_233:
#    Edge-mehraban-4.xlsx
#    Feature-mehraban-4.xlsx
#    Label-mehraban-4.xlsx
#
# ✅ sample_234:
#    Edge-mohseni.xlsx
#    Feature-mohseni.xlsx
#    Label-mohseni.xlsx
#
# ✅ sample_235:
#    Edge-moradkhani.xlsx
#    Feature-moradkhani.xlsx
#    Label-moradkhani.xlsx
#
# ✅ sample_236:
#    Edge-moradkhani2.xlsx
#    Feature-moradkhani2.xlsx
#    Label-moradkhani2.xlsx
#
# ✅ sample_237:
#    Edge-mousavi majd-2.xlsx
#    Feature-mousavi majd-2.xlsx
#    Label-mousavi majd-2.xlsx
#
# ✅ sample_238:
#    Edge-movahed.xlsx
#    Feature-movahed.xlsx
#    Label-movahed.xlsx
#
# ✅ sample_239:
#    Edge-nadali ghanbari.xlsx
#    Feature-nadali ghanbari.xlsx
#    Label-nadali ghanbari.xlsx
#
# ✅ sample_240:
#    Edge-other2.xlsx
#    Feature-other2.xlsx
#    Label-other2.xlsx
#
# ✅ sample_241:
#    Edge-otherAhoei.xlsx
#    Feature-otherAhoei.xlsx
#    Label-otherAhoei.xlsx
#
# ✅ sample_242:
#    Edge-otherKARIMI.xlsx
#    Feature-otherKARIMI.xlsx
#    Label-otherKARIMI.xlsx
#
# ✅ sample_243:
#    Edge-pp-meli-5.xlsx
#    Feature-pp-meli-5.xlsx
#    Label-pp-meli-5.xlsx
#
# ✅ sample_244:
#    Edge-rahimi.xlsx
#    Feature-rahimi.xlsx
#    Label-rahimi.xlsx
#
# ✅ sample_245:
#    Edge-sadrabadi.xlsx
#    Feature-sadrabadi.xlsx
#    Label-sadrabadi.xlsx
#
# ✅ sample_246:
#    Edge-salarieh kazem panah.xlsx
#    Feature-salarieh kazem panah.xlsx
#    Label-salarieh kazem panah.xlsx
#
# ✅ sample_247:
#    Edge-sazman.xlsx
#    Feature-sazman.xlsx
#    Label-sazman.xlsx
#
# ✅ sample_248:
#    Edge-sazmanejr.xlsx
#    Feature-sazmanejr.xlsx
#    Label-sazmanejr.xlsx
#
# ✅ sample_249:
#    Edge-seiedian sepah.xlsx
#    Feature-seiedian sepah.xlsx
#    Label-seiedian sepah.xlsx
#
# ✅ sample_250:
#    Edge-sepah.xlsx
#    Feature-sepah.xlsx
#    Label-sepah.xlsx
#
# ✅ sample_251:
#    Edge-shahidi yasan12.xlsx
#    Feature-shahidi yasan12.xlsx
#    Label-shahidi yasan12.xlsx
#
# ✅ sample_252:
#    Edge-tafresh nia.xlsx
#    Feature-tafresh nia.xlsx
#    Label-tafresh nia.xlsx
#
# ✅ sample_253:
#    Edge-top22.xlsx
#    Feature-top22.xlsx
#    Label-top22.xlsx
#
# ✅ sample_254:
#    Edge-zand.xlsx
#    Feature-zand.xlsx
#    Label-zand.xlsx
#
# Done! Created 254 sample folders

# %%
def simple_translate_features(data_dir="data/train"):

    column_translation = {
        'Element_Name': 'Element_Name',
        'سیستم سازه ای': 'Structural_System',
        'وضعیت بازشو': 'Opening_Status',
        'اختلاف ارتفاع': 'Height_Difference',
        'اختلاف مساحت سقف ها جز بام': 'Roof_Area_Difference_Excluding_Roof',
        'نسب به محور افقی': 'Relative_to_Horizontal_Axis',
        'نسبت به محور قائم\n': 'Relative_to_Vertical_Axis',
        'آرایش تیرها': 'Beam_Arrangement',
        'نسبت عرض به طول پلان': 'Width_to_Length_Ratio',
        'تعداد قاب های\n راستای افقی': 'Number_of_Horizontal_Frames',
        'تعداد قاب های \nراستای قائم': 'Number_of_Vertical_Frames',
        ' نسبت قاب های \nx به  y': 'Frame_Ratio_X_to_Y',
        'ارتفاع سازه': 'Structure_Height',
        'تعداد طبقات': 'Number_of_Floors',
        'ضریب زلزله': 'Earthquake_Coefficient',
        'دریفت مجاز': 'Allowable_Drift',
        'مقاومت فشاری\nبتن تیر': 'Beam_Concrete_Compressive_Strength',
        'مقاومت فشاری\nبتن ستون': 'Column_Concrete_Compressive_Strength',
        'تحلیل دینامیکی': 'Dynamic_Analysis',
        'تحلیل استاتیکی': 'Static_Analysis',
        'X1': 'X1',
        'Y1': 'Y1',
        'Z1': 'Z1',
        'X2': 'X2',
        'Y2': 'Y2',
        'Z2': 'Z2',
        'Length': 'Length',
        'Angle': 'Angle',
        'Story': 'Story',
        'Ele_Type': 'Ele_Type',
        'Boundary': 'Boundary',
        'Alignment': 'Alignment',
        'GravityForce': 'GravityForce',
        'EX': 'EX',
        'EY': 'EY',
        'CMX': 'CMX',
        'CRX': 'CRX',
        'DeltaX': 'DeltaX',
        'CMY': 'CMY',
        'CRY': 'CRY',
        'DeltaY': 'DeltaY',
        'CRXi': 'CRXi',
        'CRYi': 'CRYi'
    }

    data_path = Path(data_dir)
    sample_folders = [f for f in data_path.iterdir() if f.is_dir() and f.name.startswith("sample_")]
    
    print(f"Found {len(sample_folders)} sample folders")

    for folder in sorted(sample_folders):
        for ext in ['.xlsx', '.xls']:
            feature_files = list(folder.glob(f"Feature-*{ext}"))
            if feature_files:
                feature_file = feature_files[0]
                try:
                    df = pd.read_excel(feature_file)
                    df_translated = df.rename(columns=column_translation)

                    new_name = feature_file.stem + "_english.xlsx"
                    new_path = folder / new_name
                    df_translated.to_excel(new_path, index=False)
                    
                    print(f"✅ {folder.name}: Translated {feature_file.name} → {new_name}")
                    break
                except Exception as e:
                    print(f"❌ {folder.name}: Error - {str(e)}")
    
    print("\n✅ Translation complete!")

simple_translate_features("/Users/sarayetel/Desktop/Research/Graph/RC-Element-Prediction-GNN/data/train")
# Out:
# Found 254 sample folders
# ✅ sample_1: Translated Feature-02-shahidi.xlsx → Feature-02-shahidi_english.xlsx
# ✅ sample_10: Translated Feature-16_english.xlsx → Feature-16_english_english.xlsx
# ✅ sample_100: Translated Feature-CE0281-Soltani_english.xlsx → Feature-CE0281-Soltani_english_english.xlsx
# ✅ sample_101: Translated Feature-CE0284-mollavi.xlsx → Feature-CE0284-mollavi_english.xlsx
# ✅ sample_102: Translated Feature-CE0285-EramJ.xlsx → Feature-CE0285-EramJ_english.xlsx
# ✅ sample_103: Translated Feature-CE0392-DadgostariD.xlsx → Feature-CE0392-DadgostariD_english.xlsx
# ✅ sample_104: Translated Feature-CE9922-hatami_english.xlsx → Feature-CE9922-hatami_english_english.xlsx
# ✅ sample_105: Translated Feature-Chegini Sazmani B1.xlsx → Feature-Chegini Sazmani B1_english.xlsx
# ✅ sample_132: Translated Feature-Heydari2.xlsx → Feature-Heydari2_english.xlsx
# ✅ sample_133: Translated Feature-Jahangiri 02_english.xlsx → Feature-Jahangiri 02_english_english.xlsx
# ✅ sample_134: Translated Feature-Javadi Pour.xlsx → Feature-Javadi Pour_english.xlsx
# ✅ sample_135: Translated Feature-Kaj 04.xlsx → Feature-Kaj 04_english.xlsx
# ✅ sample_136: Translated Feature-Kakolivand Ejraee.xlsx → Feature-Kakolivand Ejraee_english.xlsx
# ✅ sample_137: Translated Feature-Karami.xlsx → Feature-Karami_english.xlsx
# ✅ sample_138: Translated Feature-Karegar.xlsx → Feature-Karegar_english.xlsx
# ✅ sample_139: Translated Feature-Karimi Sazmani.xlsx → Feature-Karimi Sazmani_english.xlsx
# ✅ sample_14: Translated Feature-19.xlsx → Feature-19_english.xlsx
# ✅ sample_140: Translated Feature-Karimi.xlsx → Feature-Karimi_english.xlsx
# ✅ sample_141: Translated Feature-Keshavarz.xlsx → Feature-Keshavarz_english.xlsx
# ✅ sample_142: Translated Feature-Khobroi.xlsx → Feature-Khobroi_english.xlsx
# ✅ sample_143: Translated Feature-Khoshraftar Ejraee.xlsx → Feature-Khoshraftar Ejraee_english.xlsx
# ✅ sample_144: Translated Feature-MASKAN MELI E.xlsx → Feature-MASKAN MELI E_english.xlsx
# ✅ sample_145: Translated Feature-Mehdi.xlsx → Feature-Mehdi_english.xlsx
# ✅ sample_146: Translated Feature-Memerzade.xlsx → Feature-Memerzade_english.xlsx
# ✅ sample_147: Translated Feature-Mohammadi 03 (3).xlsx → Feature-Mohammadi 03 (3)_english.xlsx
# ✅ sample_148: Translated Feature-Mohammadi 04 (2).xlsx → Feature-Mohammadi 04 (2)_english.xlsx
# ✅ sample_149: Translated Feature-Moradi Sazmani_english.xlsx → Feature-Moradi Sazmani_english_english.xlsx
# ✅ sample_15: Translated Feature-2_english.xlsx → Feature-2_english_english.xlsx
# ✅ sample_150: Translated Feature-Mosque No.1.xlsx → Feature-Mosque No.1_english.xlsx
# ✅ sample_151: Translated Feature-Movahedi Main.xlsx → Feature-Movahedi Main_english.xlsx
# ✅ sample_152: Translated Feature-Namian.xlsx → Feature-Namian_english.xlsx
# ✅ sample_153: Translated Feature-Nariman_english.xlsx → Feature-Nariman_english_english.xlsx
# ✅ sample_154: Translated Feature-Nejati 03_english.xlsx → Feature-Nejati 03_english_english.xlsx
# ✅ sample_155: Translated Feature-Nikokalam 07.xlsx → Feature-Nikokalam 07_english.xlsx
# ✅ sample_156: Translated Feature-Norouzi 04.xlsx → Feature-Norouzi 04_english.xlsx
# ✅ sample_157: Translated Feature-Octagonal Mosque_english.xlsx → Feature-Octagonal Mosque_english_english.xlsx
# ✅ sample_158: Translated Feature-Pajoheshgah 04_english.xlsx → Feature-Pajoheshgah 04_english_english.xlsx
# ✅ sample_159: Translated Feature-Pasdaran_english.xlsx → Feature-Pasdaran_english_english.xlsx
# ✅ sample_16: Translated Feature-23-mostaghimi.xlsx → Feature-23-mostaghimi_english.xlsx
